# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoAntP/Projetinhos/blob/main/BeeCrowd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exemplo que curti e quero decorar

nq = int(input("Digite a quantidade de numeros que deseja digitar"))
q = [0]*nq
for c in range(nq):
  int(input("Digite um número"))
print(q)#Me retorna uma lista com a quantidade de espaços na lista com valores 0
print(nq)#Me diz a quantidade de números digitados
# Out:
# Digite a quantidade de numeros que deseja digitar3
# Digite um número8
# Digite um número3
# Digite um número1
# [0, 0, 0]
# 3

# %%
#Exemplo que curti e quero decorar

v = int(input("Digite a quantidade de valor que você deseja digitar"))
linha_v = input()
palavras = linha_v.split()
valores = []
for c in range(v):
  valores.append(int(palavras[c]))#ele não me impede de adicionar mais valores do que input mas so mostra a quantidade definida a partir do input
print(valores)

#// No caso tambémm não me permite digitar menos valores do que o estabelecido em v
#Funções que quero descobrir como usar direito map, round e quero entender melhor try exepect
#Exemplo que curti e quero decorar

n = int(input())
palavras = input().split()
valores = list (map(int ,palavras))#pelo que entendi map e como um reforçador então ele garante que aquilo vai ser feito ex: se tenho uma função que pega um número e retorna ele mais um o map garante que isso ocorra
print(valores)
# Out:
# Digite a quantidade de valor que você deseja digitar2
# 200 23
# [200, 23]
# 2
# 720 81
# [720, 81]

# %%
#1001
A = int(input())
B = int(input())
X = A+B
print(f'X = {X}')

# %%
#1002

raio = float(input())
pi = 3.14159
area = pi * raio**2
print(f'A={area:.4f}')

# %%
#1003
A = int(input())
B = int(input())
SOMA = A+B
print(f'SOMA = {SOMA}')

# %%
#1004
A = int(input())
B = int(input())
PROD = A*B
print(f'PROD = {PROD}')

# %%
#1005
A = float(input())
B = float(input())
nota_1 = A * 0.35
nota_2 = B * 0.75
media = (nota_1 + nota_2)/1.1
print(f'MEDIA = {media:.5f}')

# %%
#1006
A = float(input())
B = float(input())
C = float(input())
nota_1 = A * 2
nota_2 = B * 3
nota_3 = C * 5
media = (nota_1 + nota_2 +nota_3)/10
print(f'MEDIA = {media:.1f}')

# %%
#1007
A = int(input())
B = int(input())
C = int(input())
D = int(input())
DIFERENCA = (A * B - C * D)
print(f'DIFERENCA = {DIFERENCA}')

# %%
#1008
n_fun = int(input())
n_hor = int(input())
valor_hor = float(input())
salary = n_hor*valor_hor
print(f'NUMBER = {n_fun}')
print(f'SALARY = U$ {salary:.2f}')

# %%
#1009
nome = str(input())
salary_fix = float(input())
n_venda = float(input())
bonus = salary_fix+(n_venda* 0.15)
print(f'TOTAL = R$ {bonus:.2f}')

# %%
#1010

linha_1 = input().split()
cod_1 = int(linha_1[0])
num_p1 = int(linha_1[1])
vl_unit1 = float(linha_1[2])

linha_2 = input().split()
cod_2 = int(linha_2[0])
num_p2 = int(linha_2[1])
vl_unit2 = float(linha_2[2])

total = num_p1*vl_unit1 + num_p2*vl_unit2

print(f'VALOR A PAGAR: R$ {total:.2f}')

###############################################################################################
cod_peca1 = int(input())
n_peca1 = int(input())
valor_peca1 = float(input())

cod_peca2 = int(input())
n_peca2 = int(input())
valor_peca2 = float(input())

media = (n_peca1 * valor_peca1 ) + (n_peca2 * valor_peca2 )

print(f'VALOR A PAGAR: R$ {media:.2f}')


codigo1, quantidade1, valor1 = input().split()
n_peca1 = int(input(quantidade1))
valor_peca1 = float(valor1)
codigo2, quantidade2, valor2 = input().split()
n_peca2 = int(input(quantidade2))
valor_peca2 = float(valor2)
media = (n_peca1 * valor_peca1 ) + (n_peca2 * valor_peca2 )
print(f'VALOR A PAGAR: R$ {media:.2f}')
# Out:
# 12 1 5.30
# 16 2 5.10
# VALOR A PAGAR: R$ 12.40

# %%
#1019
N = int(input())
h = N/3600
r = N%3600
m = r/60
s = r%60

print("%i:%i:%i"%(h,m,s))

# %%
#1021 - Não Resolvido

valor = float(input())


nota100 = 0
nota50 = 0
nota20 = 0
nota10 = 0
nota5 = 0
nota2 = 0
moeda1 = 0
moeda050 = 0
moeda025 = 0
moeda010 = 0
moeda005 = 0
moeda001 = 0

if valor >= 100{
    nota100 = valor/100

}

# %%
A = float(input())
B = float(input())
C = float(input())
D = float(input())
DIFERENCA = (A * B - C * D)
print(f'DIFERENCA = {DIFERENCA}')
# Out:
# 5
# 6
# 7
# 8
# DIFERENCA = -26.0

# %%
#1035
lista = input().split()
A = int(lista[0])
B = int(lista[1])
C = int(lista[2])
D = int(lista[3])

if (B>C and D>A) and (C+D)>(A+B)and C>0 and D > 0 and (A%2 == 0):
    print("Valores aceitos")
else:
    print("Valores nao aceitos")

# %%
#1036
import math

entrada = input().split()
a = float(entrada[0])
b = float(entrada[1])
c = float(entrada[2])

delta = b*b -4*a*c

if delta <0 or a == 0:
    print('Impossivel calcular')
else:
    x1 =( -b + math.sqrt(delta))/(2*a)
    x2 =( -b - math.sqrt(delta))/(2*a)
    print(f'R1 = %0.5f'%x1)
    print(f'R2 = %0.5f'%x2)
# Out:
# 78.0 42.6 21.4
# Impossivel calcular

# %%
#1038

entrada = input().split()
codigo = int(entrada[0])
qtd = int(entrada[1])
reps = 0.0

if codigo == 1:
    resp = 4.0 *qtd
elif codigo == 2:
    resp = 4.5 *qtd
elif codigo == 3:
    resp = 5.0 *qtd
elif codigo == 4:
    resp = 2.0 *qtd
elif codigo == 5:
    resp = 1.5 *qtd
print("Total: R$ %.2f" % resp)

# %%
#1042

lista = input().split()
A = int(lista[0])
B = int(lista[1])
C = int(lista[2])
lista = [A,B,C]
reserva = lista.copy()
lista.sort()
print(lista[0])
print(lista[1])
print(lista[2])
print('')
print(reserva[0])
print(reserva[1])
print(reserva[2])




########################### Versão Legal##############################
lista = input().split()
A = int(lista[0])
B = int(lista[1])
C = int(lista[2])
lista = [A,B,C]
revesa = lista.copy()
lista.sort()
print(lista[0])
print(lista[1])
print(lista[2])
print('')
revesa.sort(reverse=True)
print(revesa[0])
print(revesa[1])
print(revesa[2])

# %%
#LISTA 02

# %%
from math import factorial
num = int(input("Digite um numero para calcularmos seu fatorial: "))
n = factorial(num)
print(f"O fatorial de {num} é {n}")

###########################################################################
num = int(input("Digite um numero para calcularmos seu fatorial: "))
fat = 1
c = num
while c>0:
  print(f"{c}x ", end='')
  print('' if c>1  else '= ', end='')
  fat = fat*c
  c -= 1
print(f'O Fatorial de {num} e {fat}')
# Out:
# Digite um numero para calcularmos seu fatorial: 5
# O fatorial de 5 é 120
# Digite um numero para calcularmos seu fatorial: 5
# 5x 4x 3x 2x 1x = O Fatorial de 5 e 120

# %%
maior_num = 0
for nuns in range(0,10):
  num = int(input("Digite um valor"))
  if num > maior_num:
      segundo = maior_num
      maior_num = num
  else:
    maior_num = maior_num
print(maior_num)
print(segundo)
# Out:
# Digite um valor1
# Digite um valor2
# Digite um valor3
# Digite um valor4
# Digite um valor5
# Digite um valor6
# Digite um valor7
# Digite um valor8
# Digite um valor9
# Digite um valor10
# 10
# 9

# %%
#1103
https://judge.beecrowd.com/pt/problems/view/1103

# %%
#2303
L,C,M,N = input().split()
linha = int(L)
if linha <=0 and >1000
    linha = 1
colunas = int(C)
if colunas <=0 and >1000
    colunas = 1

# %%
#1049
nome = input()
if nome == 'vertebrado':
    if nome == 'ave':
    elif nome == 'mamifero'
    else:
        print('Erro')
elif nome == 'invertebrado':
    if nome == 'inseto'
    elif nome == 'anelideo'
    else:
        print('Erro')
